# %% [markdown]
# ## Chunking
#
# Chunk extraction is a useful preliminary step to information extraction, that creates parse trees from unstructured text with a chunker. Once you have a parse tree of a sentence, you can do more specific information extraction, such as named entity recognition and relation extraction.
#
# To find the chunk structure for a given sentence, the RegexpParser chunker begins with a flat structure in which no tokens are chunked. The chunking rules are applied in turn, successively updating the chunk structure. Once all of the rules have been invoked, the resulting chunk structure is returned.
#
# **Recommended Steps:**
#
# 1. Sentence tokenization of the text.
# 2. Word tokenization.
# 3. POS tagging.
# 4. Run the chunk rule.

# %% [markdown]
# So here is Mr. James Wilson who wrote about Elon Musk. Here is the following content.
#
# ~~~~
# Musk was born on June 28, 1971, in Pretoria, Gauteng, South Africa,[27] the son of Maye Musk (née Haldeman), a model and dietician from Regina, Saskatchewan, Canada;[28] and Errol Musk, a South African electromechanical engineer, pilot and sailor. He has a younger brother, Kimbal (born 1972), and a younger sister, Tosca (born 1974).[28][29][30][31] His paternal grandmother was British, and he also has Pennsylvania Dutch ancestry,[32][33] and his maternal grandfather was American, from Minnesota.[34] After his parents divorced in 1980, Musk lived mostly with his father in the suburbs of Pretoria.[32]
#
# During his childhood he had an interest in reading and often did so for hours at a time.[35]
#
# At What age did Musk got interested in computing? At age 10, he developed an interest in computing with the Commodore VIC-20.[36] He taught himself computer programming at the age of 12, sold the code for a BASIC-based video game he created called Blastar, to a magazine called PC and Office Technology, for approximately $500. [37][38] A web version of the game is available online.[37][39]
#
# Musk was severely bullied throughout his childhood, and was once hospitalized when a group of boys threw him down a flight of stairs and then beat him until he lost consciousness.[40]
#
# Musk was initially educated at private schools, attending the English-speaking Waterkloof House Preparatory School.
#
# Mr. Singh helped Musk during his initial days when he was severely bullied during his childhood.
#
# Musk later graduated from Pretoria Boys High School and moved to Canada in June 1989, just before his 18th birthday,[41] after obtaining Canadian citizenship through his Canadian-born mother.[42][43] Although at the time Musk had to register to become a Canadian citizen, Bill C-37, which came into law in April of 2009, effectively made his Canadian citizenship retroactive to his birth since he was born in the first generation abroad to a Canadian-born mother. Therefore, with the law change, he is considered to have always been a Canadian citizen by birth.
# ~~~~

# %% [markdown]
# ## Part - 1
#
#     Given the above extract find all the Noun Phrases(NP) using Chunking. Follow the recommended steps described above
#
#     A Noun Phrase can be anything which has an optional Determiner(DT) followed by any number of adjectives(JJ) followed by a Noun(NN)
#
#
# ## Part - 2
#
#     Use the built in Named Entity Extractor to extract the entities

# %% [markdown]
# #### Import ####

# %%
import nltk
import re
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import state_union
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.tokenize import wordpunct_tokenize

# %% [markdown]
# #### Text file ####

# %%
document = 'Musk was born on June 28, 1971, in Pretoria, Gauteng, South Africa,[27] the son of Maye Musk (née Haldeman),\
a model and dietician from Regina, Saskatchewan, Canada;[28] and Errol Musk, a South African electromechanical engineer, \
pilot and sailor. He has a younger brother, Kimbal (born 1972), and a younger sister, Tosca (born 1974).[28][29][30][31] \
His paternal grandmother was British, and he also has Pennsylvania Dutch ancestry,[32][33] and his maternal grandfather \
was American, from Minnesota.[34] After his parents divorced in 1980, Musk lived mostly with his father in the suburbs of\
Pretoria.[32]\
During his childhood he had an interest in reading and often did so for hours at a time.[35]\
At What age did Musk got interested in computing? At age 10, he developed an interest in computing with the Commodore\
VIC-20.[36] He taught himself computer programming at the age of 12, sold the code for a BASIC-based video game he\
created called Blastar, to a magazine called PC and Office Technology, for approximately $500. [37][38] A web version \
of the game is available online.[37][39]\
Musk was severely bullied throughout his childhood, and was once hospitalized when a group of boys threw him down a\
flight of stairs and then beat him until he lost consciousness.[40]\
Musk was initially educated at private schools, attending the English-speaking Waterkloof House Preparatory School.\
Mr. Singh helped Musk during his initial days when he was severely bullied during his childhood.\
Musk later graduated from Pretoria Boys High School and moved to Canada in June 1989, just before his 18th birthday,[41] after obtaining Canadian citizenship through his Canadian-born mother.[42][43] Although at the time Musk had to register to become a Canadian citizen, Bill C-37, which came into law in April of 2009, effectively made his Canadian citizenship retroactive to his birth since he was born in the first generation abroad to a Canadian-born mother. Therefore, with the law change, he is considered to have always been a Canadian citizen by birth.'

# %% [markdown]
# # Part - 1 #

# %%
# removing [..] from the document
out = re.sub("\[..\]", '', document)

#sentence tokenizing 
tokenized = sent_tokenize(out)

# %%
for i in tokenized:
    words = nltk.word_tokenize(i)
    tagged = nltk.pos_tag(words)
        
    ChunkGram = r"""Chunked: {<DT>?<JJ>*<NN>+} """
    ChunkParser = nltk.RegexpParser(ChunkGram)
    Chunked = ChunkParser.parse(tagged)
    #Chunked.draw()
    print (Chunked)
# Out:
# (S
#   Musk/NNP
#   was/VBD
#   born/VBN
#   on/IN
#   June/NNP
#   28/CD
#   ,/,
#   1971/CD
#   ,/,
#   in/IN
#   Pretoria/NNP
#   ,/,
#   Gauteng/NNP
#   ,/,
#   South/NNP
#   Africa/NNP
#   ,/,
#   (Chunked the/DT son/NN)
#   of/IN
#   Maye/NNP
#   Musk/NNP
#   (/(
#   née/JJ
#   Haldeman/NNP
#   )/)
#   ,/,
#   (Chunked a/DT model/NN)
#   and/CC
#   dietician/JJ
#   from/IN
#   Regina/NNP
#   ,/,
#   Saskatchewan/NNP
#   ,/,
#   Canada/NNP
#   ;/:
#   and/CC
#   Errol/NNP
#   Musk/NNP
#   ,/,
#   (Chunked a/DT South/JJ African/JJ electromechanical/JJ engineer/NN)
#   ,/,
#   (Chunked pilot/NN)
#   and/CC
#   (Chunked sailor/NN)
#   ./.)
# (S
#   He/PRP
#   has/VBZ
#   a/DT
#   younger/JJR
#   (Chunked brother/NN)
#   ,/,
#   Kimbal/NNP
#   (/(
#   born/JJ
#   1972/CD
#   )/)
#   ,/,
#   and/CC
#   a/DT
#   younger/JJR
#   (Chunked sister/NN)
#   ,/,
#   Tosca/NNP
#   (/(
#   born/JJ
#   1974/CD
#   )/)
#   ./.)
# (S
#   His/PRP$
#   (Chunked paternal/JJ grandmother/NN)
#   was/VBD
#   British/JJ
#   ,/,
#   and/CC
#   he/PRP
#   also/RB
#   has/VBZ
#   Pennsylvania/NNP
#   Dutch/NNP
#   (Chunked ancestry/NN)
#   ,/,
#   and/CC
#   his/PRP$
#   (Chunked maternal/JJ grandfather/NN)
#   was/VBD
#   American/JJ
#   ,/,
#   from/IN
#   Minnesota/NNP
#   ./.)
# (S
#   After/IN
#   his/PRP$
#   parents/NNS
#   divorced/VBN
#   in/IN
#   1980/CD
#   ,/,
#   Musk/NNP
#   lived/VBD
#   mostly/RB
#   with/IN
#   his/PRP$
#   (Chunked father/NN)
#   in/IN
#   (Chunked the/DT suburbs/NN)
#   ofPretoria.During/VBG
#   his/PRP$
#   (Chunked childhood/NN)
#   he/PRP
#   had/VBD
#   (Chunked an/DT interest/NN)
#   in/IN
#   (Chunked reading/NN)
#   and/CC
#   often/RB
#   did/VBD
#   so/RB
#   for/IN
#   hours/NNS
#   at/IN
#   (Chunked a/DT time.At/NN)
#   What/WP
#   (Chunked age/NN)
#   did/VBD
#   Musk/NNP
#   got/VBD
#   interested/JJ
#   in/IN
#   computing/VBG
#   ?/.)
# (S
#   At/IN
#   (Chunked age/NN)
#   10/CD
#   ,/,
#   he/PRP
#   developed/VBD
#   (Chunked an/DT interest/NN)
#   in/IN
#   computing/VBG
#   with/IN
#   the/DT
#   CommodoreVIC-20/NNP
#   ./.)
# (S
#   He/PRP
#   taught/VBD
#   himself/PRP
#   (Chunked computer/NN)
#   programming/VBG
#   at/IN
#   (Chunked the/DT age/NN)
#   of/IN
#   12/CD
#   ,/,
#   sold/VBD
#   (Chunked the/DT code/NN)
#   for/IN
#   (Chunked a/DT BASIC-based/JJ video/NN game/NN)
#   hecreated/VBD
#   called/VBN
#   Blastar/NNP
#   ,/,
#   to/TO
#   (Chunked a/DT magazine/NN)
#   called/VBN
#   (Chunked PC/NN)
#   and/CC
#   Office/NNP
#   Technology/NNP
#   ,/,
#   for/IN
#   approximately/RB
#   $/$
#   500/CD
#   ./.)
# (S
#   (Chunked A/DT web/JJ version/NN)
#   of/IN
#   (Chunked the/DT game/NN)
#   is/VBZ
#   (Chunked available/JJ online.Musk/NN)
#   was/VBD
#   severely/RB
#   bullied/VBN
#   throughout/IN
#   his/PRP$
#   (Chunked childhood/NN)
#   ,/,
#   and/CC
#   was/VBD
#   once/RB
#   hospitalized/VBN
#   when/WRB
#   (Chunked a/DT group/NN)
#   of/IN
#   boys/NNS
#   threw/VBD
#   him/PRP
#   down/RP
#   (Chunked aflight/NN)
#   of/IN
#   stairs/NNS
#   and/CC
#   then/RB
#   beat/VBD
#   him/PRP
#   until/IN
#   he/PRP
#   lost/VBD
#   (Chunked consciousness.Musk/NN)
#   was/VBD
#   initially/RB
#   educated/VBN
#   at/IN
#   private/JJ
#   schools/NNS
#   ,/,
#   attending/VBG
#   the/DT
#   English-speaking/JJ
#   Waterkloof/NNP
#   House/NNP
#   Preparatory/NNP
#   School.Mr/NNP
#   ./.)
# (S
#   Singh/NNP
#   helped/VBD
#   Musk/NNP
#   during/IN
#   his/PRP$
#   initial/JJ
#   days/NNS
#   when/WRB
#   he/PRP
#   was/VBD
#   severely/RB
#   bullied/VBN
#   during/IN
#   his/PRP$
#   (Chunked childhood.Musk/NN)
#   later/RB
#   graduated/VBN
#   from/IN
#   Pretoria/NNP
#   Boys/NNP
#   High/NNP
#   School/NNP
#   and/CC
#   moved/VBD
#   to/TO
#   Canada/NNP
#   in/IN
#   June/NNP
#   1989/CD
#   ,/,
#   just/RB
#   before/IN
#   his/PRP$
#   18th/CD
#   (Chunked birthday/NN)
#   ,/,
#   after/IN
#   obtaining/VBG
#   (Chunked Canadian/JJ citizenship/NN)
#   through/IN
#   his/PRP$
#   (Chunked Canadian-born/JJ mother/NN)
#   ./.)
# (S
#   Although/IN
#   at/IN
#   (Chunked the/DT time/NN)
#   Musk/NNP
#   had/VBD
#   to/TO
#   register/VB
#   to/TO
#   become/VB
#   (Chunked a/DT Canadian/JJ citizen/NN)
#   ,/,
#   Bill/NNP
#   C-37/NNP
#   ,/,
#   which/WDT
#   came/VBD
#   into/IN
#   (Chunked law/NN)
#   in/IN
#   April/NNP
#   of/IN
#   2009/CD
#   ,/,
#   effectively/RB
#   made/VBD
#   his/PRP$
#   (Chunked Canadian/JJ citizenship/NN)
#   retroactive/JJ
#   to/TO
#   his/PRP$
#   (Chunked birth/NN)
#   since/IN
#   he/PRP
#   was/VBD
#   born/VBN
#   in/IN
#   (Chunked the/DT first/JJ generation/NN)
#   abroad/RB
#   to/TO
#   (Chunked a/DT Canadian-born/JJ mother/NN)
#   ./.)
# (S
#   Therefore/RB
#   ,/,
#   with/IN
#   (Chunked the/DT law/NN change/NN)
#   ,/,
#   he/PRP
#   is/VBZ
#   considered/VBN
#   to/TO
#   have/VB
#   always/RB
#   been/VBN
#   (Chunked a/DT Canadian/JJ citizen/NN)
#   by/IN
#   (Chunked birth/NN)
#   ./.)

# %% [markdown]
# # Part - 2 named entity #

# %%
for i in tokenized:
    words = nltk.word_tokenize(i)
    tagged = nltk.pos_tag(words)

    namedEnt = nltk.ne_chunk(tagged)
    print(namedEnt)
# Out:
# (S
#   (PERSON Musk/NNP)
#   was/VBD
#   born/VBN
#   on/IN
#   June/NNP
#   28/CD
#   ,/,
#   1971/CD
#   ,/,
#   in/IN
#   (GPE Pretoria/NNP)
#   ,/,
#   (PERSON Gauteng/NNP)
#   ,/,
#   (GPE South/NNP Africa/NNP)
#   ,/,
#   the/DT
#   son/NN
#   of/IN
#   (ORGANIZATION Maye/NNP Musk/NNP)
#   (/(
#   née/JJ
#   Haldeman/NNP
#   )/)
#   ,/,
#   a/DT
#   model/NN
#   and/CC
#   dietician/JJ
#   from/IN
#   (GPE Regina/NNP)
#   ,/,
#   (GPE Saskatchewan/NNP)
#   ,/,
#   (GPE Canada/NNP)
#   ;/:
#   and/CC
#   (PERSON Errol/NNP Musk/NNP)
#   ,/,
#   a/DT
#   (GPE South/JJ)
#   (ORGANIZATION African/JJ)
#   electromechanical/JJ
#   engineer/NN
#   ,/,
#   pilot/NN
#   and/CC
#   sailor/NN
#   ./.)
# (S
#   He/PRP
#   has/VBZ
#   a/DT
#   younger/JJR
#   brother/NN
#   ,/,
#   (GPE Kimbal/NNP)
#   (/(
#   born/JJ
#   1972/CD
#   )/)
#   ,/,
#   and/CC
#   a/DT
#   younger/JJR
#   sister/NN
#   ,/,
#   (GPE Tosca/NNP)
#   (/(
#   born/JJ
#   1974/CD
#   )/)
#   ./.)
# (S
#   His/PRP$
#   paternal/JJ
#   grandmother/NN
#   was/VBD
#   (GPE British/JJ)
#   ,/,
#   and/CC
#   he/PRP
#   also/RB
#   has/VBZ
#   (PERSON Pennsylvania/NNP Dutch/NNP)
#   ancestry/NN
#   ,/,
#   and/CC
#   his/PRP$
#   maternal/JJ
#   grandfather/NN
#   was/VBD
#   (GPE American/JJ)
#   ,/,
#   from/IN
#   (GPE Minnesota/NNP)
#   ./.)
# (S
#   After/IN
#   his/PRP$
#   parents/NNS
#   divorced/VBN
#   in/IN
#   1980/CD
#   ,/,
#   (PERSON Musk/NNP)
#   lived/VBD
#   mostly/RB
#   with/IN
#   his/PRP$
#   father/NN
#   in/IN
#   the/DT
#   suburbs/NN
#   ofPretoria.During/VBG
#   his/PRP$
#   childhood/NN
#   he/PRP
#   had/VBD
#   an/DT
#   interest/NN
#   in/IN
#   reading/NN
#   and/CC
#   often/RB
#   did/VBD
#   so/RB
#   for/IN
#   hours/NNS
#   at/IN
#   a/DT
#   time.At/NN
#   What/WP
#   age/NN
#   did/VBD
#   (PERSON Musk/NNP)
#   got/VBD
#   interested/JJ
#   in/IN
#   computing/VBG
#   ?/.)
# (S
#   At/IN
#   age/NN
#   10/CD
#   ,/,
#   he/PRP
#   developed/VBD
#   an/DT
#   interest/NN
#   in/IN
#   computing/VBG
#   with/IN
#   the/DT
#   CommodoreVIC-20/NNP
#   ./.)
# (S
#   He/PRP
#   taught/VBD
#   himself/PRP
#   computer/NN
#   programming/VBG
#   at/IN
#   the/DT
#   age/NN
#   of/IN
#   12/CD
#   ,/,
#   sold/VBD
#   the/DT
#   code/NN
#   for/IN
#   a/DT
#   BASIC-based/JJ
#   video/NN
#   game/NN
#   hecreated/VBD
#   called/VBN
#   (ORGANIZATION Blastar/NNP)
#   ,/,
#   to/TO
#   a/DT
#   magazine/NN
#   called/VBN
#   (ORGANIZATION PC/NN)
#   and/CC
#   (ORGANIZATION Office/NNP Technology/NNP)
#   ,/,
#   for/IN
#   approximately/RB
#   $/$
#   500/CD
#   ./.)
# (S
#   A/DT
#   web/JJ
#   version/NN
#   of/IN
#   the/DT
#   game/NN
#   is/VBZ
#   available/JJ
#   online.Musk/NN
#   was/VBD
#   severely/RB
#   bullied/VBN
#   throughout/IN
#   his/PRP$
#   childhood/NN
#   ,/,
#   and/CC
#   was/VBD
#   once/RB
#   hospitalized/VBN
#   when/WRB
#   a/DT
#   group/NN
#   of/IN
#   boys/NNS
#   threw/VBD
#   him/PRP
#   down/RP
#   aflight/NN
#   of/IN
#   stairs/NNS
#   and/CC
#   then/RB
#   beat/VBD
#   him/PRP
#   until/IN
#   he/PRP
#   lost/VBD
#   consciousness.Musk/NN
#   was/VBD
#   initially/RB
#   educated/VBN
#   at/IN
#   private/JJ
#   schools/NNS
#   ,/,
#   attending/VBG
#   the/DT
#   English-speaking/JJ
#   (ORGANIZATION Waterkloof/NNP House/NNP)
#   Preparatory/NNP
#   School.Mr/NNP
#   ./.)
# (S
#   (PERSON Singh/NNP)
#   helped/VBD
#   (PERSON Musk/NNP)
#   during/IN
#   his/PRP$
#   initial/JJ
#   days/NNS
#   when/WRB
#   he/PRP
#   was/VBD
#   severely/RB
#   bullied/VBN
#   during/IN
#   his/PRP$
#   childhood.Musk/NN
#   later/RB
#   graduated/VBN
#   from/IN
#   (GPE Pretoria/NNP)
#   Boys/NNP
#   High/NNP
#   School/NNP
#   and/CC
#   moved/VBD
#   to/TO
#   (GPE Canada/NNP)
#   in/IN
#   June/NNP
#   1989/CD
#   ,/,
#   just/RB
#   before/IN
#   his/PRP$
#   18th/CD
#   birthday/NN
#   ,/,
#   after/IN
#   obtaining/VBG
#   (GPE Canadian/JJ)
#   citizenship/NN
#   through/IN
#   his/PRP$
#   Canadian-born/JJ
#   mother/NN
#   ./.)
# (S
#   Although/IN
#   at/IN
#   the/DT
#   time/NN
#   (PERSON Musk/NNP)
#   had/VBD
#   to/TO
#   register/VB
#   to/TO
#   become/VB
#   a/DT
#   (GPE Canadian/JJ)
#   citizen/NN
#   ,/,
#   (PERSON Bill/NNP C-37/NNP)
#   ,/,
#   which/WDT
#   came/VBD
#   into/IN
#   law/NN
#   in/IN
#   April/NNP
#   of/IN
#   2009/CD
#   ,/,
#   effectively/RB
#   made/VBD
#   his/PRP$
#   (GPE Canadian/JJ)
#   citizenship/NN
#   retroactive/JJ
#   to/TO
#   his/PRP$
#   birth/NN
#   since/IN
#   he/PRP
#   was/VBD
#   born/VBN
#   in/IN
#   the/DT
#   first/JJ
#   generation/NN
#   abroad/RB
#   to/TO
#   a/DT
#   Canadian-born/JJ
#   mother/NN
#   ./.)
# (S
#   Therefore/RB
#   ,/,
#   with/IN
#   the/DT
#   law/NN
#   change/NN
#   ,/,
#   he/PRP
#   is/VBZ
#   considered/VBN
#   to/TO
#   have/VB
#   always/RB
#   been/VBN
#   a/DT
#   (GPE Canadian/JJ)
#   citizen/NN
#   by/IN
#   birth/NN
#   ./.)
